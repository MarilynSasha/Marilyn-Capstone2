# %%
# importing and opening up row display 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows = 999

# %%
# creating dataframes from May 2020 data 
calendar_520 = pd.read_csv("/Users/TheUnit/Desktop/Marilyn_Capstone2/DATA/5.24.20.calendar.csv")
listings1_520 = pd.read_csv("~/Desktop/Marilyn_Capstone2/DATA/5.24.20.listings-2.csv")
listings2_520 = pd.read_csv("~/Desktop/Marilyn_Capstone2/DATA/5.24.20.listings.csv")
neighborhoods_520 = pd.read_csv("~/Desktop/Marilyn_Capstone2/DATA/5.24.20.neighbourhoods.csv")
reviews1_520 = pd.read_csv("~/Desktop/Marilyn_Capstone2/DATA/5.24.20.reviews-2.csv")
reviews2_520 = pd.read_csv("~/Desktop/Marilyn_Capstone2/DATA/5.24.20.reviews.csv")
# Out:
# /Users/TheUnit/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (61,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# exploring May 2020 data 
calendar_520
# Out:
#          listing_id        date available       price adjusted_price  \
# 0            246057  2020-05-26         t   $1,335.00      $1,335.00
# 1             22787  2020-05-26         t   $2,331.00      $2,331.00
# 2             22787  2020-05-27         t   $2,331.00      $2,331.00
# 3             22787  2020-05-28         t   $2,331.00      $2,331.00
# 4             22787  2020-05-29         t   $2,331.00      $2,331.00
# ...             ...         ...       ...         ...            ...
# 7906741    43527513  2021-05-21         t  $55,646.00     $55,646.00
# 7906742    43527513  2021-05-22         t  $55,671.00     $55,671.00
# 7906743    43527513  2021-05-23         t  $55,646.00     $55,646.00
# 7906744    43527513  2021-05-24         t  $55,646.00     $55,646.00
# 7906745    43527513  2021-05-25         t  $55,646.00     $55,646.00
#
#          minimum_nights  maximum_nights
# 0                  28.0            30.0
# 1                  28.0           365.0
# ...

# %%
calendar_520.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7906746 entries, 0 to 7906745
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  float64
#  6   maximum_nights  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 422.3+ MB

# %%
calendar_520.describe()
# Out:
#          listing_id  minimum_nights  maximum_nights
# count  7.906746e+06    7.906651e+06    7.906651e+06
# mean   2.811154e+07    4.412605e+00    8.426371e+02
# std    1.118411e+07    2.130088e+01    6.725190e+02
# min    2.278700e+04    1.000000e+00    1.000000e+00
# 25%    1.981058e+07    1.000000e+00    3.650000e+02
# 50%    2.990960e+07    2.000000e+00    1.125000e+03
# 75%    3.812225e+07    3.000000e+00    1.125000e+03
# max    4.352751e+07    1.122000e+03    5.000000e+04

# %%
listings1_520
# Out:
#              id                            listing_url       scrape_id  \
# 0         22787     https://www.airbnb.com/rooms/22787  20200524235857
# 1         35797     https://www.airbnb.com/rooms/35797  20200524235857
# 2         56074     https://www.airbnb.com/rooms/56074  20200524235857
# 3         58955     https://www.airbnb.com/rooms/58955  20200524235857
# 4         61792     https://www.airbnb.com/rooms/61792  20200524235857
# ...         ...                                    ...             ...
# 21657  43517931  https://www.airbnb.com/rooms/43517931  20200524235857
# 21658  43520164  https://www.airbnb.com/rooms/43520164  20200524235857
# 21659  43523985  https://www.airbnb.com/rooms/43523985  20200524235857
# 21660  43527334  https://www.airbnb.com/rooms/43527334  20200524235857
# 21661  43527513  https://www.airbnb.com/rooms/43527513  20200524235857
#
#       last_scraped                                               name  \
# ...

# %%
listings1_520.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21662 entries, 0 to 21661
# Columns: 106 entries, id to reviews_per_month
# dtypes: float64(20), int64(23), object(63)
# memory usage: 17.5+ MB

# %%
listings1_520.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        ...
#        'instant_bookable', 'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object', length=106)

# %%
listings2_520
# Out:
#              id                                               name    host_id  \
# 0         22787  Sunny suite w/ queen size bed, inside boutique...      87973
# 1         35797                                        Villa Dante     153786
# 2         56074               Great space in historical San Rafael     265650
# 3         58955                 Entire beautiful duplex in la Roma     282620
# 4         61792  Spacious Clean Quiet room (own bath) in la Con...     299558
# ...         ...                                                ...        ...
# 21657  43517931                      a media Cuadra de Reforma 222   78475678
# 21658  43520164                                     Depa en ajusco  168938330
# 21659  43523985         Un acogedor lugar, lleno de luz y plantas.   37100931
# 21660  43527334                       Estrena hermoso departamento   71849927
# 21661  43527513  3 Bedroom Apartment in Centro, CDMX [Mexico City]  346685643
#
# ...

# %%
listings2_520.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21662 entries, 0 to 21661
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              21662 non-null  int64
#  1   name                            21654 non-null  object
#  2   host_id                         21662 non-null  int64
#  3   host_name                       21662 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   21662 non-null  object
#  6   latitude                        21662 non-null  float64
#  7   longitude                       21662 non-null  float64
#  8   room_type                       21662 non-null  object
#  9   price                           21662 non-null  int64
#  10  minimum_nights                  21662 non-null  int64
#  11  number_of_reviews               21662 non-null  int64
# ...

# %%
listings2_520.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# dropping a few columns from listings2_520
updatedlistings2 =listings2_520.drop(['id', 'name', 'host_id', 'host_name','neighbourhood_group','latitude', 'longitude', 'calculated_host_listings_count',
       'availability_365'], axis=1)
updatedlistings2
# Out:
#                neighbourhood        room_type  price  minimum_nights  \
# 0                 Cuauhtémoc     Private room   2331               1
# 1      Cuajimalpa de Morelos  Entire home/apt   4457               1
# 2                 Cuauhtémoc  Entire home/apt    809               4
# 3                 Cuauhtémoc  Entire home/apt   1932               3
# 4                 Cuauhtémoc     Private room   1364               2
# ...                      ...              ...    ...             ...
# 21657             Cuauhtémoc     Private room    432               4
# 21658                Tlalpan  Entire home/apt   1705               1
# 21659          Benito Juárez     Private room    736               1
# 21660         Álvaro Obregón  Entire home/apt    669               1
# 21661             Cuauhtémoc  Entire home/apt  55602               5
#
#        number_of_reviews last_review  reviews_per_month
# 0                     57  2019-05-27               0.47
# ...

# %%
neighborhoodprice = updatedlistings2.groupby('neighbourhood')
neighborhoodprice = neighborhoodprice.mean()
neighborhoodprice = neighborhoodprice.sort_values(['price'], ascending=False)
neighborhoodprice
# Out:
#                               price  minimum_nights  number_of_reviews  \
# neighbourhood
# Xochimilco              2396.043165        3.597122           5.100719
# Iztapalapa              1862.145631        1.841424           6.495146
# Miguel Hidalgo          1762.559791        4.719523          23.965377
# Cuajimalpa de Morelos   1648.633047        5.118026           9.871245
# Cuauhtémoc              1368.058601        3.333254          34.086303
# Álvaro Obregón          1100.286413        5.246334          11.239492
# Coyoacán                 932.019839        3.620912          17.950670
# Benito Juárez            874.430519        5.619089          17.947491
# Tlalpan                  781.196903        7.030973           9.778761
# Gustavo A. Madero        779.120548        2.136986          15.860274
# La Magdalena Contreras   700.575000        3.868750           9.256250
# Venustiano Carranza      696.154018        1.718750          38.968750
# ...

# %%
xochi_520 = listings2_520[listings2_520['neighbourhood'] == 'Xochimilco']
xochi_520
# Out:
#              id                                               name    host_id  \
# 193     1455119                Quiet and beautiful room Xochimilco    3941419
# 578     4637821                      HOUSE IN XOCHIMILCO´S CHANNEL   15318964
# 653     5103240                            Cuarto con baño privado    5665059
# 782     5885058               Loft en Tepepan, Xoch. Al sur ciudad   30563170
# 922     6573928                 Room for student near schools area   34383377
# 1252    8114775                  Se renta habitación al sur del DF   42849577
# 1520    9472523                          Habitaciones en zona sur!   49092973
# 1963   11362434   Departamento en zona residencial Valle Escondido   57342938
# 2087   11884250                                       Tania & John   55126823
# 2157   12142686                     Al sur de la Ciudad Xochimilco   65187462
# 2206   12324278                   Lindo departamento en Xochimilco    3762983
# ...

# %%
xochi_520.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 193 to 21646
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              139 non-null    int64
#  1   name                            139 non-null    object
#  2   host_id                         139 non-null    int64
#  3   host_name                       139 non-null    object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   139 non-null    object
#  6   latitude                        139 non-null    float64
#  7   longitude                       139 non-null    float64
#  8   room_type                       139 non-null    object
#  9   price                           139 non-null    int64
#  10  minimum_nights                  139 non-null    int64
#  11  number_of_reviews               139 non-null    int64
# ...

# %%
# how to merge dataframes 
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html 
# saving just a newly created dataframe to a csv 
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html

# %%
# looking into a url listing of a xohimilco listing 

listings1_520.loc[listings1_520['id'] == 5103240]
# Out:
#           id                           listing_url       scrape_id  \
# 653  5103240  https://www.airbnb.com/rooms/5103240  20200524235857
#
#     last_scraped                     name  \
# 653   2020-05-25  Cuarto con baño privado
#
#                                                summary space  \
# 653  Habitaciòn en zona tranquila al sur de la ciud...   NaN
#
#                                            description experiences_offered  \
# 653  Habitaciòn en zona tranquila al sur de la ciud...                none
#
#     neighborhood_overview  ... instant_bookable is_business_travel_ready  \
# 653                   NaN  ...                f                        f
#
#     cancellation_policy require_guest_profile_picture  \
# 653            flexible                             f
#
#     require_guest_phone_verification  calculated_host_listings_count  \
# 653                                f                               2
#
#      calculated_host_listings_count_entire_homes  \
# ...

# %%
# know that the listings are in pesos NOT USD
# 182 pesos is roughly what the URL price listed is for the entry

# %%
# sorting xochi df asc

xochi_520.sort_values(by=['price'])
# Out:
#              id                                               name    host_id  \
# 653     5103240                            Cuarto con baño privado    5665059
# 6654   21957404                               Room  in Xochimilco.  160294584
# 12394  32465677                                         Dormitorio  155931555
# 19019  41265405           Cuartos en el sur de la Ciudad de México  324031465
# 17807  39915849  Habitación privada ideal para estudiar y desca...   11928644
# 17549  39610629        Recámara para 1 o 2 personas. Amp. Tepepan.  293230163
# 14274  35161077          Cómodo alojamiento en el sur de la ciudad  264802819
# 19521  41762806                                   Descanso genial!  329740410
# 11839  31622231  Se renta cuarto amueblado en calle privada. Se...  213205419
# 8970   26257811                  Dormitorio para familias pequeñas  155931555
# 14523  35550255     Recámara con todos los servicios en Xochimilco  267482026
# ...

# %%
listings1_520.loc[listings1_520['id'] == 24494628]
# Out:
#             id                            listing_url       scrape_id  \
# 8214  24494628  https://www.airbnb.com/rooms/24494628  20200524235857
#
#      last_scraped                         name  \
# 8214   2020-05-28  Por el momento sin servicio
#
#                                                 summary space  \
# 8214  CUARTO AMUEBLADO ,INDEPENDIENTE CON BAÑO PRIVA...   NaN
#
#                                             description experiences_offered  \
# 8214  CUARTO AMUEBLADO ,INDEPENDIENTE CON BAÑO PRIVA...                none
#
#      neighborhood_overview  ... instant_bookable is_business_travel_ready  \
# 8214                   NaN  ...                t                        f
#
#      cancellation_policy require_guest_profile_picture  \
# 8214            flexible                             f
#
#      require_guest_phone_verification  calculated_host_listings_count  \
# 8214                                f                               1
#
# ...

# %%
# sorting xochi df desc

xochi_520.sort_values(by=['price'],ascending=False)
# Out:
#              id                                               name    host_id  \
# 14355  35302200  En un lindo pueblito a 20 minutos de Xochimilco .  228126920
# 4526   18021063                  cuarto tranquilo en el sur del DF   69092379
# 21646  43499841           Departamento 3. Las gárgolas. Xochimilco  346421270
# 13457  33910274     Hermosa Casona Mexicana rodeada de naturaleza.  123228935
# 3398   15716008                      Charming bedroom for students   78705654
# 15408  37042997                                       CASA MIRADOR  278510893
# 8214   24494628                        Por el momento sin servicio   51710151
# 4016   17007625                Agujero hobbit en metrópolis Azteca  114009074
# 19417  41645975  Departamentos nuevos top, con alberca climatizada  212104868
# 11099  30341250                                  Visita Xochimilco  227680859
# 578     4637821                      HOUSE IN XOCHIMILCO´S CHANNEL   15318964
# ...

# %%
# finding the full info on highest priced listing 
listings1_520.loc[listings1_520['id'] == 35302200]

#price needs to be updated on this listing to 196.149
# Out:
#              id                            listing_url       scrape_id  \
# 14355  35302200  https://www.airbnb.com/rooms/35302200  20200524235857
#
#       last_scraped                                               name  \
# 14355   2020-05-28  En un lindo pueblito a 20 minutos de Xochimilco .
#
#                                                  summary space  \
# 14355  Recámara muy amplia para 2 personas , matrimon...   NaN
#
#                                              description experiences_offered  \
# 14355  Recámara muy amplia para 2 personas , matrimon...                none
#
#       neighborhood_overview  ... instant_bookable is_business_travel_ready  \
# 14355                   NaN  ...                f                        f
#
#       cancellation_policy require_guest_profile_picture  \
# 14355            flexible                             f
#
#       require_guest_phone_verification  calculated_host_listings_count  \
# ...

# %%
# upon looking at the listing URL for ONE ROOM - there is NO WAY this would be 196149 PESOS 
# listed price should be 196.149 pesos to be what it is listed as on the URL 
# need to double check some of the listing that say ROOM

# %%
xochi_520.loc[xochi_520['id'] == 35302200]
# Out:
#              id                                               name    host_id  \
# 14355  35302200  En un lindo pueblito a 20 minutos de Xochimilco .  228126920
#
#       host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 14355  Elisenda                  NaN    Xochimilco  19.25915  -99.12908
#
#           room_type   price  minimum_nights  number_of_reviews last_review  \
# 14355  Private room  196149               3                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 14355                NaN                               1               365

# %%
# updating price for this entry 
# xochi.replace[14355,'price']= 196.149

xochi_520.loc[xochi_520.price == 196.149, "id"] = 35302200
# Out:
# /Users/TheUnit/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
xochi_520.loc[xochi_520['id']==35302200]
# Out:
#              id                                               name    host_id  \
# 14355  35302200  En un lindo pueblito a 20 minutos de Xochimilco .  228126920
#
#       host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 14355  Elisenda                  NaN    Xochimilco  19.25915  -99.12908
#
#           room_type   price  minimum_nights  number_of_reviews last_review  \
# 14355  Private room  196149               3                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 14355                NaN                               1               365

# %%
xochi_520.loc[xochi_520['id'] == 35302200]
# Out:
#              id                                               name    host_id  \
# 14355  35302200  En un lindo pueblito a 20 minutos de Xochimilco .  228126920
#
#       host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 14355  Elisenda                  NaN    Xochimilco  19.25915  -99.12908
#
#           room_type   price  minimum_nights  number_of_reviews last_review  \
# 14355  Private room  196149               3                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 14355                NaN                               1               365

# %%
listings1_520.loc[listings1_520['id'] == 19624298]
# Out:
#             id                            listing_url       scrape_id  \
# 5310  19624298  https://www.airbnb.com/rooms/19624298  20200524235857
#
#      last_scraped                    name  \
# 5310   2020-05-28  La casa de los Ángeles
#
#                                                 summary  \
# 5310  Casa se encuentra dentro de un fraccionamiento...
#
#                                                   space  \
# 5310  La propiedad cuenta con 3 recámaras, la primer...
#
#                                             description experiences_offered  \
# 5310  Casa se encuentra dentro de un fraccionamiento...                none
#
#                                   neighborhood_overview  ... instant_bookable  \
# 5310  Desde niña vivo en este fraccionamiento, mi in...  ...                f
#
#      is_business_travel_ready          cancellation_policy  \
# 5310                        f  strict_14_with_grace_period
#
# ...

# %%
xochi_520.loc[xochi_520['id'] == 19624298]

# price listed correctly
# Out:
#             id                    name   host_id host_name  \
# 5310  19624298  La casa de los Ángeles  98494071    Isabel
#
#       neighbourhood_group neighbourhood  latitude  longitude     room_type  \
# 5310                  NaN    Xochimilco  19.27817  -99.13138  Private room
#
#       price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 5310   1003               2                  1  2017-07-29               0.03
#
#       calculated_host_listings_count  availability_365
# 5310                               1               362

# %%
listings1_520.loc[listings1_520['id'] == 17007625]
# Out:
#             id                            listing_url       scrape_id  \
# 4016  17007625  https://www.airbnb.com/rooms/17007625  20200524235857
#
#      last_scraped                                 name  \
# 4016   2020-06-05  Agujero hobbit en metrópolis Azteca
#
#                                                 summary space  \
# 4016  Recámara amplia, buena temperatura e iluminaci...   NaN
#
#                                             description experiences_offered  \
# 4016  Recámara amplia, buena temperatura e iluminaci...                none
#
#      neighborhood_overview  ... instant_bookable is_business_travel_ready  \
# 4016                   NaN  ...                f                        f
#
#      cancellation_policy require_guest_profile_picture  \
# 4016            flexible                             f
#
#      require_guest_phone_verification  calculated_host_listings_count  \
# 4016                                f                               1
#
# ...

# %%
xochi_520.loc[xochi_520['id'] == 17007625]

# price should be 299.5 -  needs to be adjusted
# Out:
#             id                                 name    host_id host_name  \
# 4016  17007625  Agujero hobbit en metrópolis Azteca  114009074      Lula
#
#       neighbourhood_group neighbourhood  latitude  longitude     room_type  \
# 4016                  NaN    Xochimilco  19.25044  -99.12411  Private room
#
#       price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 4016   2995               7                  1  2019-09-22               0.12
#
#       calculated_host_listings_count  availability_365
# 4016                               1               365

# %%
# updating price for this entry 
xochi_520.at[4016,'price']= 299.5

# %%
xochi_520.loc[xochi_520['id'] == 17007625]

# %%
listings1_520.loc[listings1_520['id'] == 15716008]

# %%
xochi_520.loc[xochi_520['id'] == 15716008]

# price works out

# %%
listings1_520.loc[listings1_520['id'] == 33910274]

# %%
xochi_520.loc[xochi_520['id'] == 33910274]

# room type needs to be changed to entire home

# %%
# updating room type for this entry 
xochi_520.at[13457,'room_type']= 'Entire home/apt'

# %%
xochi_520.loc[xochi_520['id'] == 33910274]

# %%
listings1_520.loc[listings1_520['id'] == 18021063]

# %%
xochi_520.loc[xochi_520['id'] == 18021063]

# price works out but strange listing because it really is one bedroom for $1200/night whch is more than some of the entire houses for air BnB
# Out:
#             id                               name   host_id        host_name  \
# 4526  18021063  cuarto tranquilo en el sur del DF  69092379  Eduardo Froylan
#
#       neighbourhood_group neighbourhood  latitude  longitude     room_type  \
# 4526                  NaN    Xochimilco  19.28494  -99.10893  Private room
#
#       price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 4526  26745               1                  0         NaN                NaN
#
#       calculated_host_listings_count  availability_365
# 4526                               1               365

# %%
xochi_520.loc[xochi_520['host_id'] == 69092379]
# Out:
#             id                               name   host_id        host_name  \
# 4526  18021063  cuarto tranquilo en el sur del DF  69092379  Eduardo Froylan
#
#       neighbourhood_group neighbourhood  latitude  longitude     room_type  \
# 4526                  NaN    Xochimilco  19.28494  -99.10893  Private room
#
#       price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 4526  26745               1                  0         NaN                NaN
#
#       calculated_host_listings_count  availability_365
# 4526                               1               365

# %%
# viewing the data desc by price - looks different than recent after updates 

xochi_520.sort_values(by=['price'],ascending=False)
# Out:
#              id                                               name    host_id  \
# 14355  35302200  En un lindo pueblito a 20 minutos de Xochimilco .  228126920
# 4526   18021063                  cuarto tranquilo en el sur del DF   69092379
# 21646  43499841           Departamento 3. Las gárgolas. Xochimilco  346421270
# 13457  33910274     Hermosa Casona Mexicana rodeada de naturaleza.  123228935
# 3398   15716008                      Charming bedroom for students   78705654
# 15408  37042997                                       CASA MIRADOR  278510893
# 8214   24494628                        Por el momento sin servicio   51710151
# 4016   17007625                Agujero hobbit en metrópolis Azteca  114009074
# 19417  41645975  Departamentos nuevos top, con alberca climatizada  212104868
# 11099  30341250                                  Visita Xochimilco  227680859
# 578     4637821                      HOUSE IN XOCHIMILCO´S CHANNEL   15318964
# ...

# %%
# creating a csv of xochi for tableau 
xochi.to_csv(r'~/Desktop/Marilyn_Capstone2/xochi.csv',index=False)

# %%
neighborhoods_520
# Out:
#     neighbourhood_group           neighbourhood
# 0                   NaN          Álvaro Obregón
# 1                   NaN            Azcapotzalco
# 2                   NaN           Benito Juárez
# 3                   NaN                Coyoacán
# 4                   NaN   Cuajimalpa de Morelos
# 5                   NaN              Cuauhtémoc
# 6                   NaN       Gustavo A. Madero
# 7                   NaN               Iztacalco
# 8                   NaN              Iztapalapa
# 9                   NaN  La Magdalena Contreras
# 10                  NaN          Miguel Hidalgo
# 11                  NaN              Milpa Alta
# 12                  NaN                 Tláhuac
# 13                  NaN                 Tlalpan
# 14                  NaN     Venustiano Carranza
# 15                  NaN              Xochimilco

# %%
# taking a look at may2019 data 
calendar_519 = pd.read_csv("/Users/TheUnit/Desktop/Marilyn_Capstone2/DATA/5.22.19.calendar.csv")
listings1_519 = pd.read_csv("~/Desktop/Marilyn_Capstone2/DATA/5.22.19.listings.csv")
listings2_519 = pd.read_csv("~/Desktop/Marilyn_Capstone2/DATA/5.22.19.listings-2.csv")
# Out:
# /Users/TheUnit/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (43,61,62,94) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
calendar_519

# %%
listings1_519

# %%
# looking at xochimilco at may 2019
xochi_2019 = listings1_519[listings1_519['neighbourhood'] == 'Xochimilco']
xochi_2019

# %%
xochi_2019.info()

# %%
# looking at prices for listings in xochimilco may 2019
xochi_2019.sort_values(by=['price'],ascending=False)

# %%
# checking may 2020 min nights for further insight
xochi_520.sort_values(by=['minimum_nights'],ascending=False)
# Out:
#              id                                               name    host_id  \
# 19019  41265405           Cuartos en el sur de la Ciudad de México  324031465
# 9936   28268639                       RECAMARA AMUEBLADA 1 PERSONA  213282230
# 21646  43499841           Departamento 3. Las gárgolas. Xochimilco  346421270
# 12020  31885633  Habitación en Xochimilco / Embarcadero y el Bo...   63564464
# 653     5103240                            Cuarto con baño privado    5665059
# 8007   24154768        Departamento ideal para oficinas y familias  182020953
# 9463   27386567             Casa en  Xochimilco para vacacionstas.  206385393
# 17807  39915849  Habitación privada ideal para estudiar y desca...   11928644
# 16151  37969970                           Suite Hermosa en Terraza  285432378
# 16115  37932440                          Suite hermosa y funcional  285432378
# 16104  37914093                          Suite Estándar muy cómoda  285432378
# ...

# %%
minstay = xochi_520.groupby('minimum_nights')
minstay.count()
# Out:
#                 id  name  host_id  host_name  neighbourhood_group  \
# minimum_nights
# 1               83    83       83         83                    0
# 2               31    31       31         31                    0
# 3               11    11       11         11                    0
# 5                1     1        1          1                    0
# 7                8     8        8          8                    0
# 21               1     1        1          1                    0
# 30               2     2        2          2                    0
# 90               2     2        2          2                    0
#
#                 neighbourhood  latitude  longitude  room_type  price  \
# minimum_nights
# 1                          83        83         83         83     83
# 2                          31        31         31         31     31
# 3                          11        11         11         11     11
# ...

# %%
# creating a csv of minstay for tableau 
minstay.to_csv(r'~/Desktop/Marilyn_Capstone2/minstay.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-61c4533f47d1> in <module>
#       1 # creating a csv of minstay for tableau
# ----> 2 minstay.to_csv(r'~/Desktop/Marilyn_Capstone2/minstay.csv',index=False)
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     579
#     580         raise AttributeError(
# --> 581             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     582         )
#     583
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'to_csv'

# %%
sns.set(rc={'figure.figsize': (15, 5)})

# %%
ax =sns.scatterplot(x = 'minimum_nights' , y = 'id', data = xochi_520, 
                    hue = 'room_type', style = 'room_type',  palette = ['blue', 'green', 'pink'])
